# %%
import json 

wiki_data = open('brazil.json')
brazil_data = json.load(wiki_data)

wiki_data2 = open('turkey.json')
turkey_data = json.load(wiki_data2)

wiki_data3 = open('egypt.json')
egypt_data = json.load(wiki_data3)

# %%
print turkey_data['top_ten']
# Out:
# {u'count': 2172, u'editors': [u'Podiaebba', u'NeoRetro', u'Berkaysnklf', u'\u3068\u3042\u308b\u767d\u3044\u732b', u'Yerevanci', u'HectorMoffet', u'Azirlazarus', u'Toksoz', u'Myxomatosis57', u'Egeymi', u'Somedifferentstuff', u'LukeSurl', u'Capscap', u'Ikiayyas', u'Kavas', u'58.104.4.94', u'Captain Conundrum', u'Quebec99', u'Abbatai', u'Lyonspen', u'58.104.15.144', u'Needbrains', u'AnomieBOT', u'HCPUNXKID', u'Eliotbates', u'Ocaasi', u'ClueBot NG', u'Jeancey', u'Nimuaq', u'176.40.226.245', u'Mstyslav Chernov', u'Jzlcdh', u'178.233.188.53', u'Ragmen', u'Medeis', u'GabrielF', u'Image2012', u'Numbersofthethegezi', u'The Madras', u'58.104.27.185', u'CherryX', u'Ail Subway', u'FunkMonk', u'Herzen', u'Mootros', u'108.49.55.22', u'58.104.16.249', u'51coin', u'John', u'Mpb eu', u'Infestor', u'85.107.217.208', u'Ahmetyal', u'Alessandro57', u'129.206.47.31', u'58.104.6.120', u'85.97.255.51', u'Harun1595', u'Ont', u'Candymoan', u'Luot', u'78.22.28.79', u'CounterWikiLies', u'88.247.45.41', u'Pecete
# ...

# %%
turkey_data['editors']
# Out:
# {u'100.2.164.92': {u'all': 1,
#   u'atbe': None,
#   u'first': u'19 September 2013, 22:19:08',
#   u'last': u'19 September 2013, 22:19:08',
#   u'minor': 0,
#   u'minorpct': u'0.00',
#   u'size': u'230.54',
#   u'urlencoded': u'100.2.164.92'},
#  u'101.173.42.148': {u'all': 4,
#   u'atbe': 216,
#   u'first': u'03 June 2013, 11:01:06',
#   u'last': u'03 June 2013, 11:15:32',
#   u'minor': 0,
#   u'minorpct': u'0.00',
#   u'size': u'75.67',
#   u'urlencoded': u'101.173.42.148'},
#  u'103.21.127.79': {u'all': 1,
#   u'atbe': None,
#   u'first': u'03 June 2013, 12:35:16',
#   u'last': u'03 June 2013, 12:35:16',
#   u'minor': 0,
#   u'minorpct': u'0.00',
#   u'size': u'80.99',
#   u'urlencoded': u'103.21.127.79'},
#  u'108.1.241.223': {u'all': 2,
#   u'atbe': 25,
#   u'first': u'01 June 2013, 17:54:28',
#   u'last': u'01 June 2013, 17:55:18',
#   u'minor': 0,
#   u'minorpct': u'0.00',
#   u'size': u'26.71',
#   u'urlencoded': u'108.1.241.223'},
#  u'108.234.240.10': {u'all': 1,
# ...

# %%
In [1]: %timeit range(1000)
# Out:
# 100000 loops, best of 3: 11.1 µs per loop

# %%
turkey_data?

# %%
for editor, editor_data in turkey_data['editors'].items():
for editor, editor_data in brazil_data['editors'].items():
for editor, editor_data in egypt_data['editors'].items():
    if ('size' > )
# Out:
# 144.63
# 218.11
# 157.14
# 32.16
# 145.65
# 213.57
# 49.26
# 174.02
# 72.84
# 232.26
# 72.08
# 46.66
# 152.69
# 166.95
# 54.61
# 163.13
# 217.97
# 226.50
# 99.55
# 2.50
# 193.57
# 176.85
# 138.89
# 144.10
# 51.11
# 26.66
# 204.00
# 142.30
# 208.64
# 204.63
# 143.76
# 46.99
# 72.65
# 119.32
# 102.17
# 102.52
# 51.73
# 127.77
# 203.74
# 127.08
# 228.36
# 100.15
# 125.65
# 214.85
# 91.14
# 169.73
# 188.85
# 176.42
# 106.90
# 154.22
# 163.52
# 139.23
# 211.28
# 45.99
# 62.13
# 217.95
# 163.85
# 123.26
# 228.66
# 55.69
# 92.64
# 213.90
# 157.18
# 154.05
# 175.92
# 71.06
# 102.16
# 92.38
# 199.38
# 47.92
# 162.23
# 203.92
# 72.24
# 139.70
# 217.41
# 64.47
# 163.32
# 163.41
# 101.46
# 96.38
# 72.62
# 110.45
# 109.07
# 166.01
# 46.31
# 129.95
# 92.70
# 230.49
# 212.03
# 72.08
# 82.03
# 92.46
# 120.33
# 70.78
# 26.21
# 204.74
# 109.17
# 9.76
# 133.38
# 214.87
# 76.08
# 53.56
# 176.36
# 166.01
# 143.62
# 102.52
# 103.13
# 47.21
# 127.25
# 51.79
# 64.23
# 72.30
# 72.28
# 32.70
# 198.26
# ...
